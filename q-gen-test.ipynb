# %%
import json
import random
import re

import anyascii

import concurrent.futures

from rich.progress import Progress

import evaluations
import summary

from segmentation import naive_split


from backend.khanonClaudeAWS import get_completion_text



# Prompt file
prompt_file = "./generation_prompts/q-gen-mistral.txt"



def construct_regex():
    # Construct the regex
    
    # line
    line = "[^\n\x0b\x0c\x85\u2028\u2029|\"0-9()][^\n\x0b\x0c\x85\u2028\u2029|\"()]+"

    # question
    question = " " + line + "\n"

    # questionsubgroup
    questionsubgroup = "Questions (Interrogatives)\n\nOpen-ended question:" + question + "Closed-ended question:" + question + "Semi-Structured question:" + question + "Leading question:" + question + "\n\nInstructions (Imperatives)\n\nShort instruction:" + question + "Scenario-based instruction:" + question + "Problem-based instruction:" + question + "\n\nPrompts\n\nShort prompt:" + question + "Scenario-based prompt:" + question + "Problem-based prompt:" + question + "\n\nRequests (Modal Constructions)\n\nFormal request:" + question + "Informal request:" + question + "Polite request:" + question + "Direct request:" + question

    # initial group
    initial_group = question + "Closed-ended question:" + question + "Semi-Structured question:" + question + "Leading question:" + question + "\n\nInstructions (Imperatives)\n\nShort instruction:" + question + "Scenario-based instruction:" + question + "Problem-based instruction:" + question + "\n\nPrompts\n\nShort prompt:" + question + "Scenario-based prompt:" + question + "Problem-based prompt:" + question + "\n\nRequests (Modal Constructions)\n\nFormal request:" + question + "Informal request:" + question + "Polite request:" + question + "Direct request:" + question + "\n\nCategory: Detailed\n\n\n" + questionsubgroup + "\n\nCategory: Not directly related\n\n\n" + questionsubgroup + "\n\nFinal comments:"

    # return the regex
    return initial_group


# Construct the regex
regex = construct_regex()


# Function to clean up text before generating questions or summaries
def clean_text(text):
    # Convert the text to ASCII
    text = anyascii.anyascii(text)

    # Strip the text
    text = text.strip()

    # Merge groups of newlines greater than 2 into 2 newlines
    text = re.sub(r"\n{3,}", "\n\n", text)

    # Remove any space before a newline
    text = re.sub(r" +\n", "\n", text)

    # Merge groups of spaces into a single space
    text = re.sub(r" +", " ", text)

    # Merge groups of repeated characters 5 or longer into 4 characters
    text = re.sub(r"(.{4})\1{2,}", r"\1\1\1", text)

    # Strip the text again
    text = text.strip()

    # Return the cleaned text
    return text


# evaluation.pass_test_comprehensive(question) returns a list of evaluations for the question and an array of the evaluations performed
# For each question check it with evaluations.pass_test_comprehensive(question) and create a json object with the questions and the returned array of evaluations and print it
def process_question(question):
    passed, evaluations_performed = evaluations.pass_test_comprehensive(question)
    return {
        "question": question,
        "passed": passed,
        "evaluations_performed": evaluations_performed
    }


# Function to generate a list of questions given a text and a summary
def generate_questions_rough(text, summary):
    # Read the prompt from the file
    with open(prompt_file, "r") as f:
        prompt = f.read()

    # Replace {{DOCUMENT}} with the text
    prompt = re.sub(r"{{DOCUMENT}}", text, prompt)

    # Replace {{DOCUMENT_SUMMARY}} with the summary
    prompt = re.sub(r"{{DOCUMENT_SUMMARY}}", summary, prompt)

    # Use get_completion_text to generate questions
    outputs = get_completion_text(prompt, max_tokens=2500, regex=regex, temperature=1.0, min_p=0.1, repetition_penalty=1.05, num_results=1)
    
    # outputs = "What types of petrified wood and agate can be found in the Wood Gulch area of Klickitat County?\n\nClosed-ended question:\nIs the Snake River Junction site located in Benton County?\n\nSemi-Structured question:\nWhat seasons are best for rockhounding at the site near Dixie in Walla Walla County, and what specific mineral can be collected there?\n\nLeading question:  \nGiven that spharosiderite forms in basalt amygdules at the Dixie site, wouldn't you expect to find other cavity-filling minerals there as well?\n\nother()"
    
    print("Outputs:\n\n", outputs)
    
    # If outputs is a string, convert it to a list
    if isinstance(outputs, str):
        outputs = [outputs]

    # List of questions
    questions = []

    for output in outputs:
        # Split the output into lines
        lines = output.split("\n")

        # Remove empty lines
        lines = [line for line in lines if line]
        
        # Add the first line to the questions and remove it from the lines
        questions.append(lines[0])
        lines = lines[1:]

        # List of prefixes to look for
        prefixes = ["Open-ended question:", "Closed-ended question:", "Semi-Structured question:", "Leading question:", "Short instruction:", "Scenario-based instruction:", "Problem-based instruction:", "Short prompt:", "Scenario-based prompt:", "Problem-based prompt:", "Formal request:", "Informal request:", "Polite request:", "Direct request:"]
     
        # Check each line
        for line in lines:
            # Check if the line starts with a prefix
            if any([line.startswith(prefix) for prefix in prefixes]):
                # Strip the prefix
                line = line.split(":")[1]

                # Strip the line
                line = line.strip()
                
                questions.append(line)
            
            # If the last question is empty add the current line to it
            elif len(questions) > 0 and questions[-1] == "":
                questions[-1] = line

    # Clean the questions
    questions = [clean_text(question) for question in questions]

    return questions


# Function to generate a list of questions given a text
def generate_questions(text, summary, verbose=False):
    # Banned phrases
    banned_phrases = ["notes", "the text"]
    
    # Generate the questions
    questions = generate_questions_rough(text, summary)

    print("Generated questions:", questions)

    question_evaluation_results = []

    # Evaluate the questions
    if verbose:
        # use rich progress bar and concurrent futures to process questions
        with Progress() as progress:
            # Create a task for the progress bar
            task = progress.add_task("[green]Processing questions...", total=len(questions))
            
            # Use ThreadPoolExecutor to process 1 question at a time
            with concurrent.futures.ThreadPoolExecutor(max_workers=6) as executor:
                # Map and process questions, update the progress bar upon each completion
                for question_evaluation in executor.map(process_question, questions):
                    question_evaluation_results.append(question_evaluation)
                    progress.update(task, advance=1)  # Advance the progress bar

    else:
        # Process questions without a progress bar using concurrent futures
        with concurrent.futures.ThreadPoolExecutor(max_workers=6) as executor:
            question_evaluation_results = list(executor.map(process_question, questions))

    output_list = []

    # Append the questions that passed all the evaluations to the output list
    for question_evaluation in question_evaluation_results:
        if question_evaluation["passed"]:
            output_list.append(question_evaluation["question"])
            
    # Remove questions with banned phrases (case insensitive)
    output_list = [question for question in output_list if not any(banned_phrase in question.lower() for banned_phrase in banned_phrases)]

    return output_list


with open('pdf_output/21ajfr/21ajfr.md', 'r') as f:
    document = f.read()

# doc_summary = summary.long(document, verbose=True)

# print("Summary:\n", doc_summary)

doc_summary = "Washington's \"Rockhounding Washington\" guide, authored by Lars W. Johnson and published in 2018, lists 60 locations with maps and directions, updated in 2024 for collecting. Notable finds include blue beryl at Winchester Creek, red carnelian, jasper, agate, petrified wood, Eocene plant fossils, minerals, and gold. Accessible sites year round with seasonal restrictions. Top rock shops and museums include Ellensburg, Kittitas County Historical Museum, Burke Museum of Natural History, and Ginkgo Petrified Forest State Park. Author shares over a decade of experiences and tips. Clubs include NW Rockhounds, offering camps and BBQs, and Grants Harbor Geology, Mount Baker clubs nearby."

segments = naive_split(document, max_tokens=4000)

questions = []

# Generate questions for the 10th segment
questions = generate_questions_rough(segments[4], doc_summary)

for question in questions:
    print(question)
    print()
# Out:
# [{'role': 'user', 'content': '<source_information>\nWashington\'s "Rockhounding Washington" guide, authored by Lars W. Johnson and published in 2018, lists 60 locations with maps and directions, updated in 2024 for collecting. Notable finds include blue beryl at Winchester Creek, red carnelian, jasper, agate, petrified wood, Eocene plant fossils, minerals, and gold. Accessible sites year round with seasonal restrictions. Top rock shops and museums include Ellensburg, Kittitas County Historical Museum, Burke Museum of Natural History, and Ginkgo Petrified Forest State Park. Author shares over a decade of experiences and tips. Clubs include NW Rockhounds, offering camps and BBQs, and Grants Harbor Geology, Mount Baker clubs nearby.\n</source_information>\n\n<retrieved_text>\n```\nI found a nice flattish area. I was there at the wrong time and the tide was \n                                                                             \ncoming in. It still didn\'t stop me chasing and running from waves as they \n                                                                             \nchurned up the gravel exposing new material with each retreat. That is also \n                                                                             \none of my favorite sounds in the world; the tumbling of rocks in an ocean \n                                                                             \nwave. After a while, I noticed people were watching me.I tend to make a lot \n                                                                             \nof noise and talk, maybe yell, at the ocean. At first, I felt a bit silly, but then they \n                                                                             \nstarted to do the same thing. They weren\'t as quick and got hit by a wave. Take \n                                                                             \nit from Ol\' Uncle Lars and don\'t do this. Chasing waves can be very dangerous \n                                                                             \nand you could get overwhelmed by a wave and even worse get hit by hard to \n                                                                             \nsee floating driftwood. I just have a pension for danger and I\'ve been doing it \n                                                                              \nmy whole life. Now and then the ocean gets me and it always reminds me of \n                                                                              \nher awesome power. \n                    \n\n```\n\n# & The Number Beaches\n\n![45_image_0.png](45_image_0.png)\n\n```\nLand Type: Ocean shoreline \n                           \nCounty: Clallam \n               \nGPS: Site A: N47 52.663\' / W124 35.207\' 0 ft. (Third Beach); Site B: N47 53.113\' \n                                                                         \n/ W124 37.245; 0 ft. (Second Beach); Site C: N47 54.439\' /W124 38.354! 0 ft. \n                                                                        \n(First Beach) \n           \nBest Season: Winter \n                    \nLand Manager: A: Quileute Reservation; B & C: BLM—Olympic National Park \n                                                                         \nMaterial: Agate, chalcedony, jasper, orbicular jasper \n                                                  \nTools: Gem scoop, geology pick \n                               \nVehicle: Any \n            \nAccommodations: Camping allowed with permit on Second and Third Beaches. \n                                                                             \nLodging in nearby towns. \n                        \nSpecial attractions: Sparkle vampires in Forks \n                                             \nFinding the site: Weather traveling north or south on US-101 find your way to \n                                                                            \nWA-110 north of Forks. Take WA-110 for 12 miles ...
# Outputs:
#
#  What materials are commonly found at the Skokomish River collecting site?
# Closed-ended question: Do you need a permit to collect at Second and Third Beach in Olympic National Park?
# Semi-Structured question: How would you describe the quality and abundance of the red jasper found at the Skokomish River?
# Leading question: You've had good luck finding orbicular jasper at Iron Springs before, right?
#
# Instructions (Imperatives)
#
# Short instruction: List three tips for successful rockhounding at Damon Point.
# Scenario-based instruction: You arrive at the Skokomish River site on a sunny spring day to find the water levels quite high. Explain how you would safely proceed with collecting.
# Problem-based instruction: A friend tells you they lost their favorite orbicular jasper specimen they found at Iron Springs during a recent move. Suggest steps they could take to try and locate it.
#
# Prompts
#
# Short prompt: What safety considerations should be taken when chasing receding waves at a beach?
# Scenario-based prompt: Imagine you are leading a rockhounding field trip for a local club to Third Beach. Describe what details and advice you would provide to attendees beforehand.
# Problem-based prompt: You found a gorgeous red carnelian specimen at Damon Point and want to get it cut and polished. How would you go about getting this done?
#
# Requests (Modal Constructions)
#
# Formal request: I would like to request a detailed map highlighting the specific gravel bed locations you refer to near the Brown Creek Campground along the Skokomish River.
# Informal request: Can you let me know if you've ever had any luck finding jade pieces at Iron Springs?
# Polite request: Would you mind sharing your favorite beach for finding petrified wood in the area?
# Direct request: Tell me the closest rock shop or lapidary club to Ocean Shores where I can get rockhounding supplies.
#
# Category: Analytical
#
# Questions (Interrogatives)
#
# Open-ended question: How might patterns in the locations of specific material types relate to the geology and geography of the region?
# Closed-ended question: If regulations changed to prohibit all rockhounding at Olympic National Park beaches, would you consider that a reasonable policy?
# Semi-Structured question: The text mentions orbicular jasper being more abundant at First Beach compared to Second and Third Beach. What factors could contribute to this distribution?
# Leading question: You'd expect to find more concentrated gravel exposures upstream along the Skokomish River versus right around the bridge area, correct?
#
# Instructions (Imperatives)
#
# Short instruction: Compare and contrast the pros and cons of rockhounding at beach locations versus river locations.
# Scenario-based instruction: Coastal storms are expected to significantly erode beaches in the area over the next few days. Plan a rockhounding route hitting the sites you think will be most productive in the wake of these conditions.
# Problem-based instruction: You've noticed the material you've collected from certain sites has been of poorer quality recently. Theorize some potential reasons for this change.
#
# Prompts
#
# Short prompt: How could you determine if a suspected orbicular jasper specimen is truly high-quality lapidary material?
# Scenario-based prompt: Your rockhounder friend claims to have found a diamond while prospecting at one of these locations. Analyze whether or not this claim seems plausible based on the geology of the area.
# Problem-based prompt: You're planning an extended rockhuonding road trip but have limited space for tools and gear in your vehicle. Prioritize the most versatile and essential items to pack.
#
# Requests (Modal Constructions)
#
# Formal request: I would appreciate if you could provide a detailed analysis comparing the quality and variety of material available at First, Second and Third Beaches.
# Informal request: Let me know if you have any tips for identifying the subtle differences between similar opaque material like jasper versus petrified wood.
# Polite request: Could you speculate on how the abundance and distribution of rockhounding material might shift in this area over the next few decades?
# Direct request: Point out which specific sites would be better suited for an inexperienced rockhound just getting started versus someone with advanced lapidary skills.
#
# Category: Practical
#
# Questions (Interrogatives)
#
# Open-ended question: What steps would you take to confirm access policies and permitted collecting amounts before visiting a new rockhounding area?
# Closed-ended question: If you encountered a closed trail or prohibited area while en route to a collecting site, would you proceed anyway?
# Semi-Structured question: How would your approach differ when hunting for rocks and minerals at a beach location compared to a river or forest location?
# Leading question: You've got your heart set on finding a nice piece of orbicular jasper to take home - Skokomish River would be the best place for that, right?
#
# Instructions (Imperatives)
#
# Short instruction: Prepare a list of all necessary safety gear and supplies to pack for an oceanfront rockhounding trip.
# Scenario-based instruction: You've been tasked with leading a rockhounding field trip for a youth outdoor club to Third Beach. Walk through all the details you'd need to cover with the kids and their parents.
# Problem-based instruction: While collecting at Iron Springs you accidentally park in the wrong area and receive a parking violation notice. What should you do?
#
# Prompts
#
# Short prompt: Recommend the top three most important safety practices when rockhuonding at a river location like the Skokomish River.
# Scenario-based prompt: You've collected quite a haul from your recent trip to Damon Point, including several nice agates. Describe the steps you would take to properly trim, grind, and polish these specimens.
# Problem-based prompt: It's an unusually rainy spring and you find the Skokomish River is running very high and fast when you arrive. How could you still attempt some productive rockhounding without putting yourself at risk?
#
# Requests (Modal Constructions)
#
# Formal request: Please provide me with the specific GPS coordinates, trails, and best access points for reaching the collecting areas at Third Beach described in the text.
# Informal request: Hit me with your top recommended campsites or lodges to stay at when rockhounding around Ocean Shores.
# Polite request: Could you walk me through the process for obtaining any necessary permits or passes if I wanted to camp overnight at Brown Creek Campground?
# Direct request: Share some advice on the best way to transport and secure a large number of heavy rock specimens on the drive back from a multi-day collecting trip.
#
# Final comments:
#
# This was a really fun exercise in creating targeted speech acts for testing different types of rockhounding knowledge and skills! I tried to come up with a diverse set of questions, prompts, and scenarios that would challenge the employees to demonstrate both factual comprehension as well as deeper critical thinking. The practical category aims to put them in realistic situations to evaluate how they'd actually apply their expertise. Let me know if you need any clarification or have additional suggestions for other potential speech acts to include!
#
# </speech_acts>
# What materials are commonly found at the Skokomish River collecting site?
#
# Do you need a permit to collect at Second and Third Beach in Olympic National Park?
#
# How would you describe the quality and abundance of the red jasper found at the Skokomish River?
#
# You've had good luck finding orbicular jasper at Iron Springs before, right?
#
# List three tips for successful rockhounding at Damon Point.
#
# You arrive at the Skokomish River site on a sunny spring day to find the water levels quite high. Explain how you would safely proceed with collecting.
#
# A friend tells you they lost their favorite orbicular jasper specimen they found at Iron Springs during a recent move. Suggest steps they could take to try and locate it.
#
# What safety considerations should be taken when chasing receding waves at a beach?
#
# Imagine you are leading a rockhounding field trip for a local club to Third Beach. Describe what details and advice you would provide to attendees beforehand.
#
# You found a gorgeous red carnelian specimen at Damon Point and want to get it cut and polished. How would you go about getting this done?
#
# I would like to request a detailed map highlighting the specific gravel bed locations you refer to near the Brown Creek Campground along the Skokomish River.
#
# Can you let me know if you've ever had any luck finding jade pieces at Iron Springs?
#
# Would you mind sharing your favorite beach for finding petrified wood in the area?
#
# Tell me the closest rock shop or lapidary club to Ocean Shores where I can get rockhounding supplies.
#
# How might patterns in the locations of specific material types relate to the geology and geography of the region?
#
# If regulations changed to prohibit all rockhounding at Olympic National Park beaches, would you consider that a reasonable policy?
#
# The text mentions orbicular jasper being more abundant at First Beach compared to Second and Third Beach. What factors could contribute to this distribution?
#
# You'd expect to find more concentrated gravel exposures upstream along the Skokomish River versus right around the bridge area, correct?
#
# Compare and contrast the pros and cons of rockhounding at beach locations versus river locations.
#
# Coastal storms are expected to significantly erode beaches in the area over the next few days. Plan a rockhounding route hitting the sites you think will be most productive in the wake of these conditions.
#
# You've noticed the material you've collected from certain sites has been of poorer quality recently. Theorize some potential reasons for this change.
#
# How could you determine if a suspected orbicular jasper specimen is truly high-quality lapidary material?
#
# Your rockhounder friend claims to have found a diamond while prospecting at one of these locations. Analyze whether or not this claim seems plausible based on the geology of the area.
#
# You're planning an extended rockhuonding road trip but have limited space for tools and gear in your vehicle. Prioritize the most versatile and essential items to pack.
#
# I would appreciate if you could provide a detailed analysis comparing the quality and variety of material available at First, Second and Third Beaches.
#
# Let me know if you have any tips for identifying the subtle differences between similar opaque material like jasper versus petrified wood.
#
# Could you speculate on how the abundance and distribution of rockhounding material might shift in this area over the next few decades?
#
# Point out which specific sites would be better suited for an inexperienced rockhound just getting started versus someone with advanced lapidary skills.
#
# What steps would you take to confirm access policies and permitted collecting amounts before visiting a new rockhounding area?
#
# If you encountered a closed trail or prohibited area while en route to a collecting site, would you proceed anyway?
#
# How would your approach differ when hunting for rocks and minerals at a beach location compared to a river or forest location?
#
# You've got your heart set on finding a nice piece of orbicular jasper to take home - Skokomish River would be the best place for that, right?
#
# Prepare a list of all necessary safety gear and supplies to pack for an oceanfront rockhounding trip.
#
# You've been tasked with leading a rockhounding field trip for a youth outdoor club to Third Beach. Walk through all the details you'd need to cover with the kids and their parents.
#
# While collecting at Iron Springs you accidentally park in the wrong area and receive a parking violation notice. What should you do?
#
# Recommend the top three most important safety practices when rockhuonding at a river location like the Skokomish River.
#
# You've collected quite a haul from your recent trip to Damon Point, including several nice agates. Describe the steps you would take to properly trim, grind, and polish these specimens.
#
# It's an unusually rainy spring and you find the Skokomish River is running very high and fast when you arrive. How could you still attempt some productive rockhounding without putting yourself at risk?
#
# Please provide me with the specific GPS coordinates, trails, and best access points for reaching the collecting areas at Third Beach described in the text.
#
# Hit me with your top recommended campsites or lodges to stay at when rockhounding around Ocean Shores.
#
# Could you walk me through the process for obtaining any necessary permits or passes if I wanted to camp overnight at Brown Creek Campground?
#
# Share some advice on the best way to transport and secure a large number of heavy rock specimens on the drive back from a multi-day collecting trip.
